# %% [markdown]
# <img src="http://imgur.com/1ZcRyrc.png" style="float: left; margin: 20px; height: 55px">
#
# # Project 1: SAT & ACT Analysis

# %% [markdown]
# ---
# # Part 1
#
# Part 1 requires knowledge of basic Python.
#
# ---

# %% [markdown]
# ## Problem Statement

# %% [markdown]
# Decide on your problem statement that will guide your analysis for this project. For guidelines, sample prompts, or inspiration, check out the README.
#
# **To-Do:** *Replace this cell with your problem statement.*

# %% [markdown]
# ### Contents:
# - [Background](#Background)
# - [Data Import & Cleaning](#Data-Import-and-Cleaning)
# - [Exploratory Data Analysis](#Exploratory-Data-Analysis)
# - [Data Visualization](#Visualize-the-Data)
# - [Conclusions and Recommendations](#Conclusions-and-Recommendations)

# %% [markdown]
# ## Background

# %% [markdown]
# The SAT and ACT are standardized tests that many colleges and universities in the United States require for their admissions process. This score is used along with other materials such as grade point average (GPA) and essay responses to determine whether or not a potential student will be accepted to the university.
#
# The SAT has two sections of the test: Evidence-Based Reading and Writing and Math ([*source*](https://www.princetonreview.com/college/sat-sections)). The ACT has 4 sections: English, Mathematics, Reading, and Science, with an additional optional writing section ([*source*](https://www.act.org/content/act/en/products-and-services/the-act/scores/understanding-your-scores.html)). They have different score ranges, which you can read more about on their websites or additional outside sources (a quick Google search will help you understand the scores for each test):
# * [SAT](https://collegereadiness.collegeboard.org/sat)
# * [ACT](https://www.act.org/content/act/en.html)
#
# Standardized tests have long been a controversial topic for students, administrators, and legislators. Since the 1940's, an increasing number of colleges have been using scores from sudents' performances on tests like the SAT and the ACT as a measure for college readiness and aptitude ([*source*](https://www.minotdailynews.com/news/local-news/2017/04/a-brief-history-of-the-sat-and-act/)). Supporters of these tests argue that these scores can be used as an objective measure to determine college admittance. Opponents of these tests claim that these tests are not accurate measures of students potential or ability and serve as an inequitable barrier to entry. Lately, more and more schools are opting to drop the SAT/ACT requirement for their Fall 2021 applications ([*read more about this here*](https://www.cnn.com/2020/04/14/us/coronavirus-colleges-sat-act-test-trnd/index.html)).

# %% [markdown]
# **To-Do:** *Fill out this cell (or edit the above cell) with any other background or information that is necessary for your problem statement.*

# %% [markdown]
# ### Choose your Data
#
# There are 10 datasets included in the [`data`](./data/) folder for this project. You are required to pick **at least two** of these to complete your analysis. Feel free to use more than two if you would like, or add other relevant datasets you find online.
#
# * [`act_2017.csv`](./data/act_2017.csv): 2017 ACT Scores by State
# * [`act_2018.csv`](./data/act_2018.csv): 2018 ACT Scores by State
# * [`act_2019.csv`](./data/act_2019.csv): 2019 ACT Scores by State
# * [`act_2019_ca.csv`](./data/act_2019_ca.csv): 2019 ACT Scores in California by School
# * [`sat_2017.csv`](./data/sat_2017.csv): 2017 SAT Scores by State
# * [`sat_2018.csv`](./data/sat_2018.csv): 2018 SAT Scores by State
# * [`sat_2019.csv`](./data/sat_2019.csv): 2019 SAT Scores by State
# * [`sat_2019_by_intended_college_major.csv`](./data/sat_2019_by_intended_college_major.csv): 2019 SAT Scores by Intended College Major
# * [`sat_2019_ca.csv`](./data/sat_2019_ca.csv): 2019 SAT Scores in California by School
# * [`sat_act_by_college.csv`](./data/sat_act_by_college.csv): Ranges of Accepted ACT & SAT Student Scores by Colleges

# %% [markdown]
# **To-Do:** *Fill out this cell with the datasets you will use for your analysis. Write a brief description of the contents for each dataset that you choose.*

# %% [markdown]
# ### Outside Research

# %% [markdown]
# Based on your problem statement and your chosen datasets, spend some time doing outside research on state policies or additional information that might be relevant. Summarize your findings below. If you bring in any outside tables or charts, make sure you are explicit about having borrowed them. If you quote any text, make sure that it renders as being quoted. **Make sure that you cite your sources.**

# %% [markdown]
# **To-Do:** *Fill out this cell with outside research or any additional background information that will support your analysis.*

# %% [markdown]
# ### Coding Challenges
#
# 1. Manually calculate mean:
#
#     Write a function that takes in values and returns the mean of the values. Create a list of numbers that you test on your function to check to make sure your function works!
#
#     *Note*: Do not use any mean methods built-in to any Python libraries to do this! This should be done without importing any additional libraries.

# %%
# Code:
def mean(lst):
    return sum(lst) / len(lst)

# %%
n_num = [1, 2, 3, 4, 5]
n = len(n_num)
  
get_sum = sum(n_num)
mean = get_sum / n
  
print("Mean / Average is: " + str(mean))
# Out:
# Mean / Average is: 3.0

# %% [markdown]
# 2. Manually calculate standard deviation:
#
#     The formula for standard deviation is below:
#
#     $$\sigma = \sqrt{\frac{1}{n}\sum_{i=1}^n(x_i - \mu)^2}$$
#
#     Where $x_i$ represents each value in the dataset, $\mu$ represents the mean of all values in the dataset and $n$ represents the number of values in the dataset.
#
#     Write a function that takes in values and returns the standard deviation of the values using the formula above. Hint: use the function you wrote above to calculate the mean! Use the list of numbers you created above to test on your function.
#
#     *Note*: Do not use any standard deviation methods built-in to any Python libraries to do this! This should be done without importing any additional libraries.

# %%
# Code:

# %%
def variance(lst, sample=True):
    total = 0
    mean_ = mean(lst)

    for value in lst:
        total += (value - mean_)**2

    if sample:
        return total / (len(lst) - 1)
    else:
        return total / len(lst)
    
def stdev(lst, sample=True):
    return variance(lst, sample)**(1/2)

# %% [markdown]
# 3. Data cleaning function:
#
#     Write a function that takes in a string that is a number and a percent symbol (ex. '50%', '30.5%', etc.) and converts this to a float that is the decimal approximation of the percent. For example, inputting '50%' in your function should return 0.5, '30.5%' should return 0.305, etc. Make sure to test your function to make sure it works!
#
# You will use these functions later on in the project!

# %%
# Code:
def pf(x):
    return float(x.strip('%'))/100
pf("100%")
# Out:
# 1.0

# %%
def p2f(x):
    return float(x.strip('%'))/100
pf('20%')
# Out:
# 0.2

# %% [markdown]
# ---
# # Part 2
#
# Part 2 requires knowledge of Pandas, EDA, data cleaning, and data visualization.
#
# ---

# %% [markdown]
# *All libraries used should be added here*

# %% [markdown]
# **- Load the data in using pandas**

# %%
# Imports:
import numpy as np
import pandas as pd
import scipy.stats as stats
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Data Import and Cleaning

# %%
# Loading each data with sat representing data from SAT scores nationally for 2017 and act doing
# the same for ACT scores nationally
# Code:
act = pd.read_csv('../data/act_2017.csv')
sat= pd.read_csv('../data/sat_2017.csv')

# %% [markdown]
# **- print the first 5 rows of each dataframe**

# %%
#Print the first 5 rows of each dataframe
act.head(5)
# Out:
#       State Participation  English  Math  Reading  Science Composite
# 0  National           60%     20.3  20.7     21.4     21.0      21.0
# 1   Alabama          100%     18.9  18.4     19.7     19.4      19.2
# 2    Alaska           65%     18.7  19.8     20.4     19.9      19.8
# 3   Arizona           62%     18.6  19.8     20.1     19.8      19.7
# 4  Arkansas          100%     18.9  19.0     19.7     19.5      19.4

# %%
sat.head()
# Out:
#         State Participation  Evidence-Based Reading and Writing  Math  Total
# 0     Alabama            5%                                 593   572   1165
# 1      Alaska           38%                                 547   533   1080
# 2     Arizona           30%                                 563   553   1116
# 3    Arkansas            3%                                 614   594   1208
# 4  California           53%                                 531   524   1055

# %% [markdown]
# **- Describe in words what each variable (column) is mean :**

# %% [markdown]
# # For the ACT table, columns are as follows:
#     # State is individual states around the U.S.
#     # Participation is the Participation rate for the ACT
#     # English is the score for English
#     # Math is the score for Math
#     # Reading is the score for Reading
#     # Composite is the average of Math, Reading, and Science

# %%
act.shape
# Out:
# (52, 7)

# %%
act.isna().sum()
# Out:
# State            0
# Participation    0
# English          0
# Math             0
# Reading          0
# Science          0
# Composite        0
# dtype: int64

# %%
act.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 52 entries, 0 to 51
# Data columns (total 7 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   State          52 non-null     object
#  1   Participation  52 non-null     object
#  2   English        52 non-null     float64
#  3   Math           52 non-null     float64
#  4   Reading        52 non-null     float64
#  5   Science        52 non-null     float64
#  6   Composite      52 non-null     object
# dtypes: float64(4), object(3)
# memory usage: 3.0+ KB

# %%
act.describe()
# Out:
#          English       Math    Reading    Science
# count  52.000000  52.000000  52.000000  52.000000
# mean   20.919231  21.173077  22.001923  21.040385
# std     2.332132   1.963602   2.048672   3.151113
# min    16.300000  18.000000  18.100000   2.300000
# 25%    19.000000  19.400000  20.475000  19.900000
# 50%    20.550000  20.900000  21.700000  21.150000
# 75%    23.300000  23.100000  24.125000  22.525000
# max    25.500000  25.300000  26.000000  24.900000

# %%
act.describe(include=object)
# Out:
#        State Participation Composite
# count     52            52        52
# unique    52            28        38
# top     Ohio          100%      19.8
# freq       1            17         3

# %%
# dtypes helps show what type of data is embedded in each column of the data frame
act.dtypes
# Out:
# State             object
# Participation     object
# English          float64
# Math             float64
# Reading          float64
# Science          float64
# Composite         object
# dtype: object

# %%
# Participation shows as an object and needs to be reassigned to a float as seen below.
act['Participation'] = act['Participation'].str.rstrip('%').astype('float') / 100.0
act.head(2)
# Out:
#       State  Participation  English  Math  Reading  Science Composite
# 0  National            0.6     20.3  20.7     21.4     21.0      21.0
# 1   Alabama            1.0     18.9  18.4     19.7     19.4      19.2

# %%
#Column names lowercase.
act.columns = map(str.lower, act.columns)
act.head()
# Out:
#       state  participation  english  math  reading  science composite
# 0  National           0.60     20.3  20.7     21.4     21.0      21.0
# 1   Alabama           1.00     18.9  18.4     19.7     19.4      19.2
# 2    Alaska           0.65     18.7  19.8     20.4     19.9      19.8
# 3   Arizona           0.62     18.6  19.8     20.1     19.8      19.7
# 4  Arkansas           1.00     18.9  19.0     19.7     19.5      19.4

# %%
act['composite'] = act['composite'].map(lambda x: float(x.replace('x','')))

# %%
act[:].dtypes
# Out:
# state             object
# participation    float64
# english          float64
# math             float64
# reading          float64
# science          float64
# composite        float64
# dtype: object

# %%
merged_column = pd.merge(plu, pf, 
                   left_on='plu_code',
                   right_on ='prodcode', 
                   how='inner')
print (merged_column)
pf.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-306-c72941dadd6e> in <module>
# ----> 1 merged_column = pd.merge(plu, pf,
#       2                    left_on='plu_code',
#       3                    right_on ='prodcode',
#       4                    how='inner')
#       5 print (merged_column)
#
# NameError: name 'plu' is not defined

# %%
df.to_csv('file1.csv')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-307-cb6e8844b1e6> in <module>
# ----> 1 df.to_csv('file1.csv')
#
# AttributeError: 'NoneType' object has no attribute 'to_csv'

# %% [markdown]
# # For the SAT table, columns are as follows:
#     # State is individual states around the U.S.
#     # Participation is Participation rate for the SAT
#     # Evidence Based Reading and Writing is score for Reading and Writing
#     # Math is the score for Math
#     # Total is the R&W score plus the Math Score

# %%
sat.shape
# Out:
# (51, 5)

# %%
sat.isna().sum()
# Out:
# State                                 0
# Participation                         0
# Evidence-Based Reading and Writing    0
# Math                                  0
# Total                                 0
# dtype: int64

# %%
sat.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51 entries, 0 to 50
# Data columns (total 5 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   State                               51 non-null     object
#  1   Participation                       51 non-null     object
#  2   Evidence-Based Reading and Writing  51 non-null     int64
#  3   Math                                51 non-null     int64
#  4   Total                               51 non-null     int64
# dtypes: int64(3), object(2)
# memory usage: 2.1+ KB

# %%
sat.describe()
# Out:
#        Evidence-Based Reading and Writing        Math        Total
# count                           51.000000   51.000000    51.000000
# mean                           569.117647  547.627451  1126.098039
# std                             45.666901   84.909119    92.494812
# min                            482.000000   52.000000   950.000000
# 25%                            533.500000  522.000000  1055.500000
# 50%                            559.000000  548.000000  1107.000000
# 75%                            613.000000  599.000000  1212.000000
# max                            644.000000  651.000000  1295.000000

# %%
sat.describe(include=object)
# Out:
#        State Participation
# count     51            51
# unique    51            34
# top     Ohio            3%
# freq       1             8

# %%
# dtypes helps show what type of data is embedded in each column of the data frame
sat.dtypes
# Out:
# State                                 object
# Participation                         object
# Evidence-Based Reading and Writing     int64
# Math                                   int64
# Total                                  int64
# dtype: object

# %% [markdown]
# **Fix any errors :**

# %%
sat['Participation'] = sat['Participation'].str.rstrip('%').astype('float') / 100.0
sat.head(2)
# Out:
#      State  Participation  Evidence-Based Reading and Writing  Math  Total
# 0  Alabama           0.05                                 593   572   1165
# 1   Alaska           0.38                                 547   533   1080

# %%
#Column names lowercase.
sat.columns = map(str.lower, sat.columns)
sat.head()
# Out:
#         state  participation  evidence-based_reading_and_writing  math  total
# 0     Alabama           0.05                                 593   572   1165
# 1      Alaska           0.38                                 547   533   1080
# 2     Arizona           0.30                                 563   553   1116
# 3    Arkansas           0.03                                 614   594   1208
# 4  California           0.53                                 531   524   1055

# %% [markdown]
# **- Replace :**

# %%
#replace the contain spaces with underscores:
sat.columns = sat.columns.str.replace(' ','_')
sat.head(2)
# Out:
#      state  participation  evidence-based_reading_and_writing  math  total
# 0  Alabama           0.05                                 593   572   1165
# 1   Alaska           0.38                                 547   533   1080

# %% [markdown]
# **- Merge the dataframes on the state column**

# %%
#merge both the SAT and ACT DataFrames
merge_data = pd.merge(sat, act, how='inner', on='state')
merge_data.dtypes
merge_data.head()
# Out:
#         state  participation_x  evidence-based_reading_and_writing  math_x  \
# 0     Alabama             0.05                                 593     572
# 1      Alaska             0.38                                 547     533
# 2     Arizona             0.30                                 563     553
# 3    Arkansas             0.03                                 614     594
# 4  California             0.53                                 531     524
#
#    total  participation_y  english  math_y  reading  science  composite
# 0   1165             1.00     18.9    18.4     19.7     19.4       19.2
# 1   1080             0.65     18.7    19.8     20.4     19.9       19.8
# 2   1116             0.62     18.6    19.8     20.1     19.8       19.7
# 3   1208             1.00     18.9    19.0     19.7     19.5       19.4
# 4   1055             0.31     22.5    22.7     23.1     22.2       22.8

# %%
#Change the names of the columns we can use .rename to make the columns more redable:
combined = merge_data.rename(columns={'participation_x':'sat_participation', 'math_x':'sat_math', 
                           'evidence-based_reading_and_writing':'sat_reading_writing',
                           'participation_y':'act_participation','english':'act_english',
                           'math_y':'act_math', 'reading':'act_reading', 'science':'act_science',
                           'composite':'act_composite'
                          })
combined.head(2)
# Out:
#      state  sat_participation  sat_reading_writing  sat_math  total  \
# 0  Alabama               0.05                  593       572   1165
# 1   Alaska               0.38                  547       533   1080
#
#    act_participation  act_english  act_math  act_reading  act_science  \
# 0               1.00         18.9      18.4         19.7         19.4
# 1               0.65         18.7      19.8         20.4         19.9
#
#    act_composite
# 0           19.2
# 1           19.8

# %% [markdown]
# **- Save your cleaned and merged dataframes as csv file**

# %%
#code:
combined.to_csv('cleaned_data_act_sat', index=False)

# %%
combined.head()
# Out:
#         state  sat_participation  sat_reading_writing  sat_math  total  \
# 0     Alabama               0.05                  593       572   1165
# 1      Alaska               0.38                  547       533   1080
# 2     Arizona               0.30                  563       553   1116
# 3    Arkansas               0.03                  614       594   1208
# 4  California               0.53                  531       524   1055
#
#    act_participation  act_english  act_math  act_reading  act_science  \
# 0               1.00         18.9      18.4         19.7         19.4
# 1               0.65         18.7      19.8         20.4         19.9
# 2               0.62         18.6      19.8         20.1         19.8
# 3               1.00         18.9      19.0         19.7         19.5
# 4               0.31         22.5      22.7         23.1         22.2
#
#    act_composite
# 0           19.2
# 1           19.8
# 2           19.7
# 3           19.4
# 4           22.8

# %%
# here we use .min and .max to get the minimum and maximum values for all of the columns 
print ('Minimum Values are \n', combined.min(axis=0, numeric_only=True))
print ('Maximum Values are \n', combined.max(axis=0, numeric_only=True))
# Out:
# Minimum Values are
#  sat_participation        0.02
# sat_reading_writing    482.00
# sat_math                52.00
# total                  950.00
# act_participation        0.08
# act_english             16.30
# act_math                18.00
# act_reading             18.10
# act_science              2.30
# act_composite           17.80
# dtype: float64
# Maximum Values are
#  sat_participation         1.0
# sat_reading_writing     644.0
# sat_math                651.0
# total                  1295.0
# act_participation         1.0
# act_english              25.5
# act_math                 25.3
# act_reading              26.0
# act_science              24.9
# act_composite            25.5
# dtype: float64

# %%
combined.dtypes
# Out:
# state                   object
# sat_participation      float64
# sat_reading_writing      int64
# sat_math                 int64
# total                    int64
# act_participation      float64
# act_english            float64
# act_math               float64
# act_reading            float64
# act_science            float64
# act_composite          float64
# dtype: object

# %% [markdown]
# # Data Dictionary

# %% [markdown]
# |Feature|Type|Dataset|Description|
# |:---:|:---:|:---:|:---|
# |**State**|*object*|ACT/SAT|The US state under consideration|
# |**sat_participation**|*float64*|SAT|percentage of high school students (freshman through senior) in the state that took the SAT in 2017|
# |**sat_reading_writing**|*int64*|SAT|scaled score between 200-800 (inclusive) measuring verbal reasoning, averaged over all test takers in state in 2017|
# |**sat_math** |*int64*|SAT|scaled score between 200-800 (inclusive) measuring mathematical reasoning, averaged over all test takers in a state in 2017|
# |**total**|*int64*|SAT|sum of verbal and reading score, averaged over all test takers in a state in 2017|
# |**act_participation**|*float64*|ACT|percentage of high school students (freshman through senior) in the state that took the ACT in 2017|
# |**act_english**|*float64*|ACT|scaled score between 1-36 (inclusive) measuring command of grammar, averaged over all test takers in a state in 2017
# |
# |**act_math**|*float64*|ACT|scaled score between 1-36 (inclusive) measuring mathematical reasoning, averaged over all test takers in a state in 2017|
# |**act_reading**|*float64*|ACT|scaled score between 1-36 (inclusive) measuring reading comprehension, averaged over all test takers in a state in 2017
# |
# |**act_science**|*float64*|ACT|scaled score between 1-36 (inclusive) measuring scientific reasoning, averaged over all test takers in a state in 2017
# |
# |**act_composite**|*float64*|ACT|mean of English, Math, Reading, and Science scores, averaged over all test takers in state in 2017
# |

# %% [markdown]
# # Exploratory Data Analysis

# %% [markdown]
# ### 1.Summary Statistics

# %%
combined.describe().T.head()
# Out:
#                      count         mean        std     min      25%      50%  \
# sat_participation     51.0     0.398039   0.352766    0.02     0.04     0.38
# sat_reading_writing   51.0   569.117647  45.666901  482.00   533.50   559.00
# sat_math              51.0   547.627451  84.909119   52.00   522.00   548.00
# total                 51.0  1126.098039  92.494812  950.00  1055.50  1107.00
# act_participation     51.0     0.652549   0.321408    0.08     0.31     0.69
#
#                          75%     max
# sat_participation       0.66     1.0
# sat_reading_writing   613.00   644.0
# sat_math              599.00   651.0
# total                1212.00  1295.0
# act_participation       1.00     1.0

# %%
combined['total'].describe()
# Out:
# count      51.000000
# mean     1126.098039
# std        92.494812
# min       950.000000
# 25%      1055.500000
# 50%      1107.000000
# 75%      1212.000000
# max      1295.000000
# Name: total, dtype: float64

# %%
#Histogram National SAT Scores
combined['total'].hist(color = 'pink');

# %% [markdown]
# **Participation rates
# Histogram of 2017 participation rate show the difference in test participation . Both tests show bimodal tendency in which states have either high (near 100%) or low (below 30%) participation but little in between. Very few states have 50% participation on both tests.**

# %% [markdown]
# **2.Use a dictionary comprehension
# to apply the standard deviation function you create in part 1 to each numeric column in the dataframe. No loops.**

# %%
#code
def std_dev(some_list):
    mean_sum = 0
    for num in some_list: 
        mean_sum += num
    mean_list = mean_sum/len(some_list)
    
    var_sum = 0
    for num in some_list: 
        var_sum += ((num - mean_list) ** 2)
    std_list = (var_sum * (1/len(some_list))) ** (1/2)
    
    return std_list

# %%
#testing std_dev() function .
std_dev(combined['sat_reading_writing'])
# Out:
# 45.21697020437866

# %% [markdown]
# - Use a **dictionary comprehension** to apply your standard deviation function to each numeric column in the dataframe. No loops
# - Assign the output to variable sd as a dictionary where:
# - Each column name is now a key
# - That standard deviation of the column is the value
# - Example Output : {'ACT_Math': 120, 'ACT_Reading': 120, ...}

# %%
#calling a specific column title from combined dataframe
combined.columns[3]
# Out:
# 'sat_math'

# %%
# Use a dictionary comprhension to store the standard deviations of the numeric columns
sd = {x: std_dev(combined[x]) for x in combined.columns if combined[x].dtypes != object}
sd
# Out:
# {'sat_participation': 0.3492907076664507,
#  'sat_reading_writing': 45.21697020437866,
#  'sat_math': 84.07255521608297,
#  'total': 91.58351056778743,
#  'act_participation': 0.3182417575123181,
#  'act_english': 2.3304876369363363,
#  'act_math': 1.9624620273436781,
#  'act_reading': 2.0469029314842646,
#  'act_science': 3.1511078954644076,
#  'act_composite': 2.000786081581989}

# %% [markdown]
# ## Investigate trends in the data.

# %% [markdown]
# **
# Investigate trends in the data
# Using sorting and/or masking (along with the .head method to not print our entire dataframe), consider the following questions:
#
# Which states have the highest and lowest participation rates for the:
#
# 2017 SAT?
#
# 2017 ACT?
#
# Which states have the highest and lowest mean total/composite scores for the:
#
# 2017 SAT?
#
# 2017 ACT?
#
# Do any states with 100% participation on a given test have a rate change year-to-year?
#
# Do any states show have >50% participation on both tests either year?
#
# Based on what you've just observed, have you identified any states that you're especially interested in? Make a note of these
#
# and state why you think they're interesting.
#
# You should comment on your findings at each step in a markdown cell below your code block. Make sure you include at least one example of sorting your dataframe by a column, and one example of using boolean filtering (i.e., masking) to select a subset of the dataframe.

# %%
#Creating a mask to show only States with ACT or SAT Participation above 90%
mask = (combined['act_participation'] > 0.9) | (combined['sat_participation'] > 0.9)
combined[mask][['act_participation', 'sat_participation']].sort_values('act_participation', ascending=False).head()
# Out:
#     act_participation  sat_participation
# 0                 1.0               0.05
# 23                1.0               0.03
# 49                1.0               0.03
# 44                1.0               0.03
# 42                1.0               0.05

# %%
# Sort by highest SAT 2017 participation
combined.sort_values('sat_participation', ascending = False).head()
# Out:
#                    state  sat_participation  sat_reading_writing  sat_math  \
# 8   District of Columbia               1.00                  482       468
# 22              Michigan               1.00                  509       495
# 6            Connecticut               1.00                  530       512
# 7               Delaware               1.00                  503       492
# 29         New Hampshire               0.96                  532       520
#
#     total  act_participation  act_english  act_math  act_reading  act_science  \
# 8     950               0.32         24.4      23.5         24.9         23.5
# 22   1005               0.29         24.1      23.7         24.5         23.8
# 6    1041               0.31         25.5      24.6         25.6         24.6
# 7     996               0.18         24.1      23.4         24.8         23.6
# 29   1052               0.18         25.4      25.1         26.0         24.9
#
#     act_composite
# 8            24.2
# ...

# %%
# Sort by  lowest SAT 2017 participation
combined.sort_values('sat_participation', ascending = True).head()
# Out:
#            state  sat_participation  sat_reading_writing  sat_math  total  \
# 34  North Dakota               0.02                  635       621   1256
# 24   Mississippi               0.02                  634       607   1242
# 15          Iowa               0.02                  641       635   1275
# 25      Missouri               0.03                  640       631   1271
# 44          Utah               0.03                  624       614   1238
#
#     act_participation  act_english  act_math  act_reading  act_science  \
# 34               0.98         19.0      20.4         20.5         20.6
# 24               1.00         18.2      18.1         18.8         18.8
# 15               0.67         21.2      21.3         22.6         22.1
# 25               1.00         19.8      19.9         20.8         20.5
# 44               1.00         19.5      19.9         20.8         20.6
#
#     act_composite
# 34           20.3
# 24           18.6
# 15           21.9
# ...

# %%
# Sort by highest ACT 2017 participation
combined.sort_values('act_participation', ascending = False).head()
# Out:
#         state  sat_participation  sat_reading_writing  sat_math  total  \
# 0     Alabama               0.05                  593       572   1165
# 17   Kentucky               0.04                  631       616   1247
# 49  Wisconsin               0.03                  642       649   1291
# 44       Utah               0.03                  624       614   1238
# 42  Tennessee               0.05                  623       604   1228
#
#     act_participation  act_english  act_math  act_reading  act_science  \
# 0                 1.0         18.9      18.4         19.7         19.4
# 17                1.0         19.6      19.4         20.5         20.1
# 49                1.0         19.7      20.4         20.6         20.9
# 44                1.0         19.5      19.9         20.8         20.6
# 42                1.0         19.5      19.2         20.1         19.9
#
#     act_composite
# 0            19.2
# 17           20.0
# 49           20.5
# 44           20.3
# ...

# %%
# Sort by  lowest ACT 2017 participation
combined.sort_values('act_participation', ascending = True).head()
# Out:
#             state  sat_participation  sat_reading_writing  sat_math  total  \
# 19          Maine               0.95                  513       499   1012
# 29  New Hampshire               0.96                  532       520   1052
# 7        Delaware               1.00                  503       492    996
# 39   Rhode Island               0.71                  539       524   1062
# 38   Pennsylvania               0.65                  540       531   1071
#
#     act_participation  act_english  act_math  act_reading  act_science  \
# 19               0.08         24.2      24.0         24.8         23.7
# 29               0.18         25.4      25.1         26.0         24.9
# 7                0.18         24.1      23.4         24.8         23.6
# 39               0.21         24.0      23.3         24.7         23.4
# 38               0.23         23.4      23.4         24.2         23.3
#
#     act_composite
# 19           24.3
# 29           25.5
# 7            24.1
# ...

# %%
# Sort by highest mean SAT_Total 2017 
combined.sort_values('total', ascending = False).head()
# Out:
#         state  sat_participation  sat_reading_writing  sat_math  total  \
# 23  Minnesota               0.03                  644       651   1295
# 49  Wisconsin               0.03                  642       649   1291
# 15       Iowa               0.02                  641       635   1275
# 25   Missouri               0.03                  640       631   1271
# 16     Kansas               0.04                  632       628   1260
#
#     act_participation  act_english  act_math  act_reading  act_science  \
# 23               1.00         20.4      21.5         21.8         21.6
# 49               1.00         19.7      20.4         20.6         20.9
# 15               0.67         21.2      21.3         22.6         22.1
# 25               1.00         19.8      19.9         20.8         20.5
# 16               0.73         21.1      21.3         22.3         21.7
#
#     act_composite
# 23           21.5
# 49           20.5
# 15           21.9
# 25           20.4
# ...

# %%
# Sort by highest mean ACT_composite 2017 
combined.sort_values('act_composite', ascending = False).head()
# Out:
#                    state  sat_participation  sat_reading_writing  sat_math  \
# 29         New Hampshire               0.96                  532       520
# 21         Massachusetts               0.76                  555       551
# 6            Connecticut               1.00                  530       512
# 19                 Maine               0.95                  513       499
# 8   District of Columbia               1.00                  482       468
#
#     total  act_participation  act_english  act_math  act_reading  act_science  \
# 29   1052               0.18         25.4      25.1         26.0         24.9
# 21   1107               0.29         25.4      25.3         25.9         24.7
# 6    1041               0.31         25.5      24.6         25.6         24.6
# 19   1012               0.08         24.2      24.0         24.8         23.7
# 8     950               0.32         24.4      23.5         24.9         23.5
#
#     act_composite
# 29           25.5
# ...

# %%
# Sort by lowest  mean SAT_total 2017 
combined.sort_values('total', ascending = True).head()
# Out:
#                    state  sat_participation  sat_reading_writing  sat_math  \
# 8   District of Columbia               1.00                  482       468
# 7               Delaware               1.00                  503       492
# 12                 Idaho               0.93                  513       493
# 22              Michigan               1.00                  509       495
# 19                 Maine               0.95                  513       499
#
#     total  act_participation  act_english  act_math  act_reading  act_science  \
# 8     950               0.32         24.4      23.5         24.9         23.5
# 7     996               0.18         24.1      23.4         24.8         23.6
# 12   1005               0.38         21.9      21.8         23.0         22.1
# 22   1005               0.29         24.1      23.7         24.5         23.8
# 19   1012               0.08         24.2      24.0         24.8         23.7
#
#     act_composite
# 8            24.2
# ...

# %%
# Sort by lowest  mean ACT_composite 2017 
combined.sort_values('act_composite', ascending = True).head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-8994dafd2e37> in <module>
#       1 # Sort by lowest  mean ACT_composite 2017
# ----> 2 combined.sort_values('act_composite', ascending = True).head()
#
# NameError: name 'combined' is not defined

# %%
# Get the states with 100% ACT 2017 participation
combined.sort_values('act_participation', ascending = True).head()
# Out:
#             state  sat_participation  sat_reading_writing  sat_math  total  \
# 19          Maine               0.95                  513       499   1012
# 29  New Hampshire               0.96                  532       520   1052
# 7        Delaware               1.00                  503       492    996
# 39   Rhode Island               0.71                  539       524   1062
# 38   Pennsylvania               0.65                  540       531   1071
#
#     act_participation  act_english  act_math  act_reading  act_science  \
# 19               0.08         24.2      24.0         24.8         23.7
# 29               0.18         25.4      25.1         26.0         24.9
# 7                0.18         24.1      23.4         24.8         23.6
# 39               0.21         24.0      23.3         24.7         23.4
# 38               0.23         23.4      23.4         24.2         23.3
#
#     act_composite
# 19           24.3
# 29           25.5
# 7            24.1
# ...

# %%
# Sort by lowest ACT 2017 participation
combined.sort_values('act_participation', ascending = True).head()
# Out:
#             state  sat_participation  sat_reading_writing  sat_math  total  \
# 19          Maine               0.95                  513       499   1012
# 29  New Hampshire               0.96                  532       520   1052
# 7        Delaware               1.00                  503       492    996
# 39   Rhode Island               0.71                  539       524   1062
# 38   Pennsylvania               0.65                  540       531   1071
#
#     act_participation  act_english  act_math  act_reading  act_science  \
# 19               0.08         24.2      24.0         24.8         23.7
# 29               0.18         25.4      25.1         26.0         24.9
# 7                0.18         24.1      23.4         24.8         23.6
# 39               0.21         24.0      23.3         24.7         23.4
# 38               0.23         23.4      23.4         24.2         23.3
#
#     act_composite
# 19           24.3
# 29           25.5
# 7            24.1
# ...

# %%
#the states with 100% participation on a SAT test 

mask1 = combined['sat_participation'] == 1.00
combined[mask1][['state', 'sat_participation', 'total']].sort_values('total').head(10)
# Out:
#                    state  sat_participation  total
# 8   District of Columbia                1.0    950
# 7               Delaware                1.0    996
# 22              Michigan                1.0   1005
# 6            Connecticut                1.0   1041

# %%
#the states with 100% participation on a ACT test 

mask2 = combined['act_participation'] == 1.00
combined[mask2][['state', 'act_participation', 'act_composite']].sort_values('act_composite').head(70)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-bda8752cebb6> in <module>
#       1 #the states with 100% participation on a ACT test
#       2
# ----> 3 mask2 = combined['act_participation'] == 1.00
#       4 combined[mask2][['state', 'act_participation', 'act_composite']].sort_values('act_composite').head(70)
#       5
#
# NameError: name 'combined' is not defined

# %% [markdown]
# #### States with ACT Contracts
# **WE have states that require ACT for state testing and have very high if not 100% participation rates. These States are important for the College Board to know about**

# %%
ACT_Contracted_States_2017 = list(combined[mask2]['state'].values)

#Created a list that will be shraed with the College Board administrators. 

ACT_Contracted_States_2017
# Out:
# ['Alabama',
#  'Arkansas',
#  'Colorado',
#  'Kentucky',
#  'Louisiana',
#  'Minnesota',
#  'Mississippi',
#  'Missouri',
#  'Montana',
#  'Nevada',
#  'North Carolina',
#  'Oklahoma',
#  'South Carolina',
#  'Tennessee',
#  'Utah',
#  'Wisconsin',
#  'Wyoming']

# %% [markdown]
# ## Visualize the Data

# %%
ticks_list = ['ACT \'17 Participation', 'ACT \'17 English', 'ACT \'17 Math', 'ACT \'17 Reading,', 'ACT \'17 Science',
              'ACT \'17 Composite', 'SAT \'17 Participation', 'SAT \'17 Reading', 'SAT \'17 Math', 'SAT \'17 Total',]

plt.subplots(figsize = (10, 8))
plt.title("SAT-ACT 2017 Correlation Heatmap")
correlations = combined[combined.columns[:-4]].corr()

#mask = np.zeros_like(correlations, dtype=np.bool)
#mask[np.triu_indices_from(mask)] = True
#add mask=mask as a parameter to sns.heatmap to remove redundant top right half of the matrix. 

ax = sns.heatmap(correlations, cmap='pink', annot=True)

# %%
#The following code uses Seaborn to make scatterplots of all the data showing the relationships to each other.
g = sns.pairplot(combined)

# %% [markdown]
# **Each boxplot below can be analysed in the same way. The leftmost part of the boxplot is what is called the lower whisker. The end of the lower wisker contains the lowest value in each of the plots. The line that extends from the whisker to the start of the box is called the quartile group 1 meaning 25% of scores fall within this range. The leftmost part of the blue box is what is called the Lower Quartile, meaning 25% of scores precede it and 75% of scores are after the lower quartile. The lower quartile extends untill the line in the middle called the median. This area between the lower quartile and the median is what is called quartile group 2.The median marks the 50% point of data, meaning half of the data precedes it and half of the data follows it. in the range from the median to the right side of the box we can find the quartile group 3. The right side of the box is called the upper quartile where it marks the 75% mark. After the upper quartile, we can find the upper whisker where the data ends at 100% of the scores.**

# %%
sns.boxplot(combined['act_participation'])
plt.title('ACT Participation 2017', fontsize = 16)
plt.xlabel('Participation in percent');
# Out:
# C:\Users\Malek\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
sns.boxplot(combined['sat_participation'])
plt.title('SAT Participation 2017', fontsize = 16)
plt.xlabel('Participation in percent');
# Out:
# C:\Users\Malek\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# ## Average Scores :

# %%
sns.boxplot(combined['act_english'])
plt.title('Average ACT English Scores 2017', fontsize = 16)
plt.xlabel('Scores out of 36');
# Out:
# C:\Users\Malek\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
sns.boxplot(combined['act_math'])
plt.title('Average ACT Math Scores 2017', fontsize = 16)
plt.xlabel('Scores out of 36');
# Out:
# C:\Users\Malek\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
sns.boxplot(combined['act_reading'])
plt.title('Average ACT Reading Scores 2017', fontsize = 16)
plt.xlabel('Scores out of 36');
# Out:
# C:\Users\Malek\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
sns.boxplot(combined['act_science'])
plt.title('Average ACT Science Scores 2017', fontsize = 16)
plt.xlabel('Scores out of 36');
# Out:
# C:\Users\Malek\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
sns.boxplot(combined['sat_reading_writing'])
plt.title('Average SAT Ecidence-Based Reading and Writing Scores 2017', fontsize = 16)
plt.xlabel('Scores out of 800');
# Out:
# C:\Users\Malek\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
sns.boxplot(combined['sat_math'])
plt.title('Average SAT Math Scores 2017', fontsize = 16)
plt.xlabel('Scores out of 800');
# Out:
# C:\Users\Malek\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
sns.boxplot(combined['act_math_17'])
plt.title('Average ACT Math Scores 2017', fontsize = 16)
plt.xlabel('Scores out of 36');

# %%
combined.head()
# Out:
#         state  sat_participation  sat_reading_writing  sat_math  total  \
# 0     Alabama               0.05                  593       572   1165
# 1      Alaska               0.38                  547       533   1080
# 2     Arizona               0.30                  563       553   1116
# 3    Arkansas               0.03                  614       594   1208
# 4  California               0.53                  531       524   1055
#
#    act_participation  act_english  act_math  act_reading  act_science  \
# 0               1.00         18.9      18.4         19.7         19.4
# 1               0.65         18.7      19.8         20.4         19.9
# 2               0.62         18.6      19.8         20.1         19.8
# 3               1.00         18.9      19.0         19.7         19.5
# 4               0.31         22.5      22.7         23.1         22.2
#
#    act_composite
# 0           19.2
# 1           19.8
# 2           19.7
# 3           19.4
# 4           22.8

# %%
def plot_scatterplot(combined, xaxis, yaxis):
    sns.scatterplot(combined[xaxis],df[yaxis])

# %%
plt.figure(figsize = (16,24))

ax1 = plt.subplot(5,1,1)
ax1.hist(combined['sat_participation'], color = 'lightsteelblue')
ax1.set_title('Mean SAT Scores 2017')

ax2 = plt.subplot(5, 1, 2, sharex=ax1)
ax2.hist(combined['act_participation'], color = 'slategrey')
ax2.set_title('Mean ACT Scores 2017')
# Out:
# Text(0.5, 1.0, 'Mean ACT Scores 2017')

# %% [markdown]
# **SAT Participation 2017**
#
# The spread of the data is from 2 to 100 with a central tendency (mean) of 38. There is no visible shape but we can say that it is slightly right skewed since the median falls to the left of the mean.

# %% [markdown]
# **ACT Participation 2017**
#
# The spread of the data is from 8 to 100 with a central tendency (mean) of 66. There is no visible shape but we can say that it is slightly left skewed since the median falls to the right of the mean.

# %% [markdown]
# ### Descriptive Statistics

# %% [markdown]
# **From the distribution, we can notice that the average of the ACT test tends to be
# 100%. As for SAT test, the skewness tends to the left,
# which mean that the number of states accepting the ACT teast**

# %% [markdown]
# **ACT Participation:** The distribution for ACT Participation in the US is biomodal and therefore not normally distributed. There is a central tendency around 60 percent participation, with a concrentation around 100 (due to state contracts), as well as a concentration around 30 percent.possibly due to an increase in SAT participation on 2017

# %% [markdown]
# **SAT Participation:** The distribution for SAT Participation is multimodal and not normally distributed. There is a significant concentration around 5 percent (due to high ACT participation for those states), as well as sub-modes around 60% and 95% participation. The distribution has a central tendency around 40% for 2017.

# %% [markdown]
# **We do not observe a normal distribution for any of the data**. This is because there is a tendency for test score to correlate negatively with participation. This tends to create biomodal distributions, where tests with high participation have lower mean scores, while those with low participation tend to have higher mean score. The lower participation-high score trend reflects some self selection bias, in which students who are seeking out that test unrequired might likely prepare for it more than students who are required to take the exam.

# %% [markdown]
# **Is it appropriate to compare these specific SAT and ACT math scores?
# Why or why not?**
#
# I think it is valuable to compare the distributions. If the SAT distributions differs greatly from the ACT, it might point to differences in the difficult or accessibility of the exam to students, as the populations across states that take these exams might be relatively similar.

# %% [markdown]
# **2017 ACT Contracted States:** Alabama, Arkansas, Colorado, Kentucky, Louisiana, Minnesota, Mississippi, Missouri, Montana, Nevada, North Carolina, Oklahoma, South Carolina, Tennessee, Utah, Wisconsin, Wyoming

# %% [markdown]
# ### Outside Research

# %% [markdown]
# **If we compare the participation rates there is a considerable difference between the number of high school students taking the ACT vs. the SAT across the United States. Over the last few years it has been the trend that the ACT has inched ahead in popularity.**
#
# ACT participation in the lower 48 states
# ![picACT.png](attachment:picACT.png)

# %% [markdown]
# SAT Participation in the lower 48 states
# ![picSAT.png](attachment:picSAT.png)

# %% [markdown]
# **The above visuals very clearly indicate strong geographic preference for the ACT over the SAT in the Midwest, South and Southwest. SAT however trumps the ACT in being the exam of choice in the Northeast, Texas and Pacific states. Nationally there is about a 60% participation rate for the ACT v/s a 40% participation rate for the SAT.
# The ACT on the other hand is mandatory in 14 states and 17 states which recorded 100% participation whereas SAT recorded 100% participation in only in Connecticut, Delaware, DC and Michigan.**

# %% [markdown]
#  ### SAT college graduation rates 2021

# %% [markdown]
# [College Graduation Statistics](https://educationdata.org/number-of-college-graduates )

# %% [markdown]
# **Delaware**
# 65.4% of bachelor’s degree recipients graduate from public institutions.
#
# **District of Columbia**
# 36.3% graduate with bachelor’s degrees each year.
#
# **Connecticut**
# 53.4% graduate with bachelor’s degrees each year
#
# **Michigan**
# 52.8% graduate with bachelor’s degrees each year.

# %% [markdown]
#  ### ACT college graduation rates 2021

# %% [markdown]
# **Wisconsin**
# 59.6% graduate with bachelor’s degrees each year.
#
# **Alabama**
# 53.6% of students earn bachelor’s degrees each year
#
# **Colorado**
# 53.4% graduate with bachelor’s degrees each year
#
# **Louisiana**
# 57.6% graduate with bachelor’s degrees each year

# %% [markdown]
# ![number-of-college-graduates.png](attachment:number-of-college-graduates.png)

# %% [markdown]
# ## Conclusions and Recommendations¶
# Based on your exploration of the data, what are you key takeaways and recommendations? Make sure to answer your question of interest or address your problem statement here.
#
# To-Do: Edit this cell with your conclusions and recommendations.
#
# Don't forget to create your README!
#
# To-Do: If you combine your problem statement, data dictionary, brief summary of your analysis, and conclusions/recommendations, you have an amazing README.md file that quickly aligns your audience to the contents of your project. Don't forget to cite your data sources!
